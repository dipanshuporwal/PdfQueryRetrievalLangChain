# %%
# !pip install langchain
# !pip install openai
# !pip install PyPDF2
# !pip install faiss-cpu
# !pip install tiktoken

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import FAISS

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
# provide the path of  pdf file/files.
pdfreader = PdfReader('leave.pdf')

# %%
from typing_extensions import Concatenate
# read text from pdf
raw_text = ''
for i, page in enumerate(pdfreader.pages):
    content = page.extract_text()
    if content:
        raw_text += content

# %%
raw_text
# Out:
# 'F.R. & S.R. – PART III \n \nCENTRAL CIVIL SERVICES \n \nLEAVE RULES CENTRAL CIVIL SERVICES \n \nLEAVE RULES  \n \nCHAPTER I \n \nPreliminary  \n \n1. Short title and commencement    \n(1) These rules may be called the Central Civil Services (Leave) \nRules, 1972. \n \n (2)  They  shall come into force on the 1\nst day of June, 1972. \n \n2. Extent of application  \n \n Save as otherwise provided in thes e rules, these rules shall apply to \nGovernment servants appointed to the civil services and posts in \nconnection with the affairs of th e Union, but shall not apply to- \n \n(a) Railway servants; (b) persons in casual or daily -rated or part-time employment; \n(c) persons paid from contingencies; \n(d) workmen employed in industrial establishments; (e) persons employed in work-charged establishments; \n(f) members of the All India Services; \n(g) persons locally recruited for se rvice in Diplomatic, Consular or \nother Indian establishments in foreign countries; \n(h) persons employed on contract ex cept when the contract provides \notherwise; \n(i) persons in respect of whom special provisions have been made \nby or under the provisions of th e Constitution or any other law \nfor the time being in force; \n(j) persons governed, for purposes  of leave, by the Fundamental \nRules or the Civil Service Regulations; \n(k) persons serving under a Centr al Government Department, on \ndeputation from a State Government  or any other source, for a \nlimited duration. \n \n3. Definitions \n \n(1) In these rules, unless the context otherwise requires- \n \n(a) “Administrator” means an Admi nistrator of a Union Territory; \n(b) “Audit Officer” means the Accounts and Audit Officer, \nwhatever his official designation,  in whose circle the office of \nthe Government servant is situated; (c) “Authority competent to gran t leave” means the authority \nspecified in Column (3) of the First Schedule to these rules, \ncompetent to grant the kind of leave specified in the \ncorresponding entries in Column (2) of the said Schedule; \n(d) “Completed years of servi ce” or “one year’s continuous \nservice” means continuous servi ce of specified duration under \nthe Central Government and in cludes the period spent on duty \nas well as on leave includi ng extraordinary leave; \n(e) [“Date of retirement” or “date of his retirement” in relation to \na Government servant, means th e afternoon of the last day of \nthe month in which the Government servant attains the age prescribed for retirement un der the terms and conditions \ngoverning his services.] \n(f) “Department of the Central G overnment” means a Ministry or \na Department of the Central G overnment as notified from time \nto time and includes the Planning Commission, the \nDepartment of Parliamentar y Affairs, the President’s \nSecretariat, the Vice-President ’s Secretariat,  the Cabinet \nSecretariat and the Prime Minister’s Secretariat; \n(g) “Foreign service” means se rvice in which a Government \nservant receives his pay with the sanction of Government from \nany source other than the Consolidated Fund of India or the \nConsolidated Fund of any State  [or the Consolidated Fund of \na Union Territory]; \n(h) “Form” means a Form append ed to the Second Schedule to \nthese rules; \n \n(i) Government servant in qua si-permanent employ” means- \n \n(A) an officer who, having been declared by the Union \nPublic Service Commission to be eligible for appointment \nto the Ministerial Services of the Government of India, has \nbeen appointed to a temporary or officiating vacancy on the understanding given to him in writing before he took up the \nappointment, that that vacancy  is expected to become \npermanent but is not confirmed after completion of three years’ continuous service; \n \n(B) an officer who may be declared as quasi-permanent \nunder the Central Civil Services (Temporary Services) Rules, 1965. \n \n(j) “Government servant in permanent employ” means an officer \nwho holds substanti ...

# %%
# We need to split the text using Character Text Split such that it sshould not increse token size
text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 800,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

# %%
len(texts)
# Out:
# 185

# %%
# Download embeddings from OpenAI
embeddings = OpenAIEmbeddings()

# %%
document_search = FAISS.from_texts(texts, embeddings)

# %%
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import OpenAI

# %%
chain = load_qa_chain(OpenAI(), chain_type="stuff")

# %%
query = "Regulation of claim to leave"
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' A Government servant’s claim to leave is regulated by the rules in force at the time the leave is applied for and granted.'

# %%
query = "Acceptance of service or employment while on leave"
docs = document_search.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# ' A Government servant (other than a Government servant who has been permitted a limited amount of private practice or who has been permitted to undertake casual literary work or service as an examiner or similar employment) while on leave, including leave preparatory to retirement, shall not take up any service or employment elsewhere, including the setting up of a private professional practice as accountant, consultant or legal or medical practitioner, without obtaining the previous sanction of the President, if the proposed services or employment lies elsewhere than in India, or the authority empowered to appoint him, if the proposed service or employment lies in India.'

# %%
from langchain.document_loaders import OnlinePDFLoader

# %%
loader = OnlinePDFLoader("https://arxiv.org/pdf/1706.03762.pdf")

# %%
# !pip install unstructured

# %%
data = loader.load()

# %%
data

# %%
# Download embeddings from OpenAI
embeddings = OpenAIEmbeddings()

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.6-py3-none-any.whl (405 kB)
#      -------------------------------------- 405.5/405.5 kB 1.6 MB/s eta 0:00:00
# Collecting tqdm>=4.65.0
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from chromadb) (1.23.5)
# Requirement already satisfied: requests>=2.28 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from chromadb) (2.28.1)
# Collecting pulsar-client>=3.1.0
#   Downloading pulsar_client-3.2.0-cp310-cp310-win_amd64.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 4.4 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.2
#   Using cached tokenizers-0.13.3-cp310-cp310-win_amd64.whl (3.5 MB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.15.1-cp310-cp310-win_amd64.whl (6.7 MB)
#      ---------------------------------------- 6.7/6.7 MB 2.5 MB/s eta 0:00:00
# Collecting typing-extensions>=4.5.0
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: pydantic<2.0,>=1.9 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from chromadb) (1.10.12)
# Collecting fastapi<0.100.0,>=0.95.2
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.4/58.4 kB 3.2 MB/s eta 0:00:00
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 67.3/67.3 kB 3.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting importlib-resources
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Collecting chroma-hnswlib==0.7.2
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ---------------------------------------- 59.5/59.5 kB 3.1 MB/s eta 0:00:00
# Collecting overrides>=7.3.1
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting starlette<0.28.0,>=0.27.0
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ---------------------------------------- 67.0/67.0 kB 1.8 MB/s eta 0:00:00
# Collecting protobuf
#   Downloading protobuf-4.24.1-cp310-abi3-win_amd64.whl (430 kB)
#      -------------------------------------- 430.4/430.4 kB 3.0 MB/s eta 0:00:00
# Collecting flatbuffers
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: sympy in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: packaging in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (22.0)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      -------------------------------------- 46.0/46.0 kB 761.2 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>2.1 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: six>=1.5 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: certifi in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from pulsar-client>=3.1.0->chromadb) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: colorama in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.65.0->chromadb) (0.4.6)
# Requirement already satisfied: click>=7.0 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.0.4)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB 3.2 MB/s eta 0:00:00
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.0-cp310-cp310-win_amd64.whl (145 kB)
#      -------------------------------------- 145.4/145.4 kB 2.9 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.19.0-cp37-abi3-win_amd64.whl (270 kB)
#      -------------------------------------- 270.9/270.9 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Collecting websockets>=10.4
#   Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl (124 kB)
#      -------------------------------------- 124.7/124.7 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.5.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dipanshu.porwal\appdata\local\anaconda3\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.2.0)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB 1.8 MB/s eta 0:00:00
# Building wheels for collected packages: chroma-hnswlib, pypika
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53835 sha256=5f487be85fecb7c58adcd9525cb53b2d757a4472b6de56815b26b23f6f4283b8
#   Stored in directory: c:\users\dipanshu.porwal\appdata\local\pip\cache\wheels\c4\41\b6\f76a356f0791da799545c23894ceae842eeff054d0eb1fb626
# Successfully built pypika
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [5 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'hnswlib' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: Could not build wheels for chroma-hnswlib, which is required to install pyproject.toml-based projects

# %%
from langchain.indexes import VectorstoreIndexCreator
index = VectorstoreIndexCreator().from_loaders([loader])

# %%
query = "Explain me about Attention is all you need"
index.query(query)
